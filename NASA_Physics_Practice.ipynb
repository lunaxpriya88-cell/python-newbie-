# %% [markdown]
# <a href="https://colab.research.google.com/github/lunaxpriya88-cell/python-newbie-/blob/main/NASA_Physics_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_str_1='Hello'
my_str_2='world!'

str_plus_str = my_str_1 +' '+ my_str_2
print(str_plus_str)

name = 'Priya'
age = 14
my_str_1 = 'Hello'
my_str_2 = "Worlds"



name_add_age = name
name_add_age += str(age)
print(name_add_age)
# Out:
# Hello world!
# Priya14
